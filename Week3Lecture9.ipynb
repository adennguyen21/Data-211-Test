# %% [markdown]
# APIs: (Application Programming Interface)
#     - Facilitate downloading their data using programming languages.

# %%
from newsapi import NewsApiClient

news_api = NewsApiClient(api_key="e24c74d4271e40ff8dbd22328f152f09")

articles = news_api.get_everything(q="Artificial intelligence", language="en", page_size=3)

for article in articles["articles"]:
    print(article["title"])
    print(article["source"]["name"])
    print("")
# Out:
# Government by AI? Trump Admin Plans to Write Regulations Using Artificial Intelligence
# Gizmodo.com
#
# AI-Powered Disinformation Swarms Are Coming for Democracy
# Wired
#
# Games Workshop Rejects the Abominable Intelligence
# Gizmodo.com

# %% [markdown]
# JSON and XML:

# %%
import json

content = """{
    "title": "COVID-19",
    "author": "world health organization",
    "date": "7/8/2022",
    "confirmed": "551 million"
}"""
json_content = json.loads(content)
print(json_content['author']) # --> world health organization
# Out:
# world health organization

# %% [markdown]
# Data visualization:

# %% [markdown]
# Rescaling:

# %%
from sklearn.preprocessing import StandardScaler
data = [[10, 90], [12, 96], [9, 120], [13, 112], [8, 88]]
print(data)

scaler = StandardScaler()
data = scaler.fit_transform(data)

print(data) #avg after scaling becomes around 0.
# Out:
# [[10, 90], [12, 96], [9, 120], [13, 112], [8, 88]]
# [[-0.21566555 -0.88721395]
#  [ 0.86266219 -0.41192076]
#  [-0.75482941  1.48925199]
#  [ 1.40182605  0.85552774]
#  [-1.29399328 -1.04564501]]
